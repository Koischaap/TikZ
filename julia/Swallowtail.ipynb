# %% [markdown]
# # Swallowtail catastrophe on Julia
#
# In this example, we draw the swallowtail catastrophe along with its double point curves.
#
# Load the plotting module and select the JavaScript Plotly frontend.
# [Click here for more information on modules](https://docs.julialang.org/en/v1/manual/modules/#modules).

# %%
using Plots
plotlyjs();
# Out:
# WebIO._IJuliaInit()

# %% [markdown]
# Generate a net of sample points using [ranges](https://docs.julialang.org/en/v1/base/math/#Base.range/) and [the `reshape` function](https://docs.julialang.org/en/v1/base/arrays/#Base.reshape).

# %%
x = -1:.1:1;
y = -.75:.1:.75;

xx = reshape([xi for xi in x for yj in y], length(y), length(x));
yy = reshape([yj for xi in x for yj in y], length(y), length(x));

# %% [markdown]
# Define the parametric surface to be plotted.

# %%
swallowtail(x,y) = (2*y.^3+x.*y, x, -3*y.^4-x.*y.^2);

# %% [markdown]
# Introduce the desired parameters. Don't forget to use `st` or nothing will show up!

# %%
plot3d(swallowtail(xx, yy),
    st = :surface,               # solid surface (not mesh)
    c = reverse(                 # reverse gradient
    cgrad(:ocean,alpha=.5)       # gradient with opacity (alpha) set to 50%
    ),
    legend = false,              # no gradient sidebar
    axis = nothing,              # no axes
    border = :none)              # no borders
# Out:
#     <div id="71f20b84-21c2-4820-9c9f-a63c4d1db258" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('71f20b84-21c2-4820-9c9f-a63c4d1db258', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(255, 255, 255, 0.500)"
#             ],
#             [
#                 0.010101010101010055,
#                 "rgba(247, 251, 252, 0.500)"
#             ],
#             [
#                 0.02020202020202022,
#                 "rgba(240, 247, 250, 0.500)"
#             ],
#             [
#                 0.030303030303030276,
#                 "rgba(232, 243, 247, 0.500)"
#             ],
#             [
#                 0.04040404040404044,
#                 "rgba(224, 240, 245, 0.500)"
#             ],
#             [
#                 0.0505050505050505,
#                 "rgba(216, 236, 242, 0.500)"
#             ],
#             [
#                 0.06060606060606055,
#                 "rgba(209, 232, 240, 0.500)"
#             ],
#             [
#                 0.07070707070707072,
#                 "rgba(201, 228, 237, 0.500)"
#             ],
#             [
#                 0.08080808080808077,
#                 "rgba(193, 224, 234, 0.500)"
#             ],
#             [
#                 0.09090909090909094,
#                 "rgba(185, 220, 232, 0.500)"
#             ],
#             [
#                 0.101010101010101,
#                 "rgba(178, 216, 229, 0.500)"
#             ],
#             [
#                 0.11111111111111116,
#                 "rgba(170, 212, 227, 0.500)"
#             ],
#             [
#                 0.12121212121212122,
#                 "rgba(162, 209, 224, 0.500)"
#             ],
#             [
#                 0.13131313131313127,
#                 "rgba(155, 205, 222, 0.500)"
#             ],
#             [
#                 0.14141414141414144,
#                 "rgba(147, 201, 219, 0.500)"
#             ],
#             [
#                 0.1515151515151515,
#                 "rgba(139, 197, 216, 0.500)"
#             ],
#             [
#                 0.16161616161616166,
#                 "rgba(131, 193, 214, 0.500)"
#             ],
#             [
#                 0.1717171717171717,
#                 "rgba(124, 189, 211, 0.500)"
#             ],
#             [
#                 0.18181818181818177,
#                 "rgba(116, 185, 209, 0.500)"
#             ],
#             [
#                 0.19191919191919193,
#                 "rgba(108, 182, 206, 0.500)"
#             ],
#             [
#                 0.202020202020202,
#                 "rgba(100, 178, 203, 0.500)"
#             ],
#             [
#                 0.21212121212121215,
#                 "rgba(93, 174, 201, 0.500)"
#             ],
#             [
#                 0.2222222222222222,
#                 "rgba(85, 170, 198, 0.500)"
#             ],
#             [
#                 0.23232323232323238,
#                 "rgba(77, 166, 196, 0.500)"
#             ],
#             [
#                 0.24242424242424243,
#                 "rgba(70, 162, 193, 0.500)"
#             ],
#             [
#                 0.2525252525252525,
#                 "rgba(62, 158, 191, 0.500)"
#             ],
#             [
#                 0.26262626262626265,
#                 "rgba(54, 155, 188, 0.500)"
#             ],
#             [
#                 0.2727272727272727,
#                 "rgba(46, 151, 185, 0.500)"
#             ],
#             [
#                 0.2828282828282829,
#                 "rgba(39, 147, 183, 0.500)"
#             ],
#             [
#                 0.29292929292929293,
#                 "rgba(31, 143, 180, 0.500)"
#             ],
#             [
#                 0.303030303030303,
#                 "rgba(23, 139, 178, 0.500)"
#             ],
#             [
#                 0.31313131313131315,
#                 "rgba(15, 135, 175, 0.500)"
#             ],
#             [
#                 0.3232323232323232,
#                 "rgba(8, 131, 173, 0.500)"
#             ],
#             [
#                 0.33333333333333337,
#                 "rgba(0, 127, 170, 0.500)"
#             ],
#             [
#                 0.3434343434343434,
#                 "rgba(0, 124, 167, 0.500)"
#             ],
#             [
#                 0.3535353535353535,
#                 "rgba(0, 120, 165, 0.500)"
#             ],
#             [
#                 0.36363636363636365,
#                 "rgba(0, 116, 162, 0.500)"
#             ],
#             [
#                 0.3737373737373737,
#                 "rgba(0, 112, 160, 0.500)"
#             ],
#             [
#                 0.38383838383838387,
#                 "rgba(0, 108, 157, 0.500)"
#             ],
#             [
#                 0.3939393939393939,
#                 "rgba(0, 104, 155, 0.500)"
#             ],
#             [
#                 0.4040404040404041,
#                 "rgba(0, 100, 152, 0.500)"
#             ],
#             [
#                 0.41414141414141414,
#                 "rgba(0, 97, 149, 0.500)"
#             ],
#             [
#                 0.4242424242424242,
#                 "rgba(0, 93, 147, 0.500)"
#             ],
#             [
#                 0.43434343434343436,
#                 "rgba(0, 89, 144, 0.500)"
#             ],
#             [
#                 0.4444444444444444,
#                 "rgba(0, 85, 142, 0.500)"
#             ],
#             [
#                 0.4545454545454546,
#                 "rgba(0, 81, 139, 0.500)"
#             ],
#             [
#                 0.46464646464646464,
#                 "rgba(0, 77, 137, 0.500)"
#             ],
#             [
#                 0.4747474747474747,
#                 "rgba(0, 73, 134, 0.500)"
#             ],
#             [
#                 0.48484848484848486,
#                 "rgba(0, 70, 131, 0.500)"
#             ],
#             [
#                 0.4949494949494949,
#                 "rgba(0, 66, 129, 0.500)"
#             ],
#             [
#                 0.505050505050505,
#                 "rgba(0, 62, 126, 0.500)"
#             ],
#             [
#                 0.5151515151515151,
#                 "rgba(0, 58, 124, 0.500)"
#             ],
#             [
#                 0.5252525252525253,
#                 "rgba(0, 54, 121, 0.500)"
#             ],
#             [
#                 0.5353535353535354,
#                 "rgba(0, 50, 118, 0.500)"
#             ],
#             [
#                 0.5454545454545454,
#                 "rgba(0, 46, 116, 0.500)"
#             ],
#             [
#                 0.5555555555555556,
#                 "rgba(0, 42, 113, 0.500)"
#             ],
#             [
#                 0.5656565656565656,
#                 "rgba(0, 39, 111, 0.500)"
#             ],
#             [
#                 0.5757575757575757,
#                 "rgba(0, 35, 108, 0.500)"
#             ],
#             [
#                 0.5858585858585859,
#                 "rgba(0, 31, 106, 0.500)"
#             ],
#             [
#                 0.595959595959596,
#                 "rgba(0, 27, 103, 0.500)"
#             ],
#             [
#                 0.6060606060606061,
#                 "rgba(0, 23, 100, 0.500)"
#             ],
#             [
#                 0.6161616161616161,
#                 "rgba(0, 19, 98, 0.500)"
#             ],
#             [
#                 0.6262626262626263,
#                 "rgba(0, 15, 95, 0.500)"
#             ],
#             [
#                 0.6363636363636364,
#                 "rgba(0, 12, 93, 0.500)"
#             ],
#             [
#                 0.6464646464646464,
#                 "rgba(0, 8, 90, 0.500)"
#             ],
#             [
#                 0.6565656565656566,
#                 "rgba(0, 4, 88, 0.500)"
#             ],
#             [
#                 0.6666666666666667,
#                 "rgba(0, 0, 85, 0.500)"
#             ],
#             [
#                 0.6767676767676767,
#                 "rgba(0, 4, 82, 0.500)"
#             ],
#             [
#                 0.6868686868686869,
#                 "rgba(0, 8, 80, 0.500)"
#             ],
#             [
#                 0.696969696969697,
#                 "rgba(0, 12, 77,

# %% [markdown]
# We move onto the curves. Using `!` will keep the existing graphics so we can draw on top of them!

# %%
plot3d!(swallowtail(-2*y.^2,y),
    line = (5, :dash),
    c = :orange)

# this is just to make it look better
y=-.45:.05:.45

plot3d!(swallowtail(-6*y.^2,y),
    line = (5, :dash),
    c = :red)
# Out:
#     <div id="bb160054-aa98-44bf-a58f-9a378330d91f" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('bb160054-aa98-44bf-a58f-9a378330d91f', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(255, 255, 255, 0.500)"
#             ],
#             [
#                 0.010101010101010055,
#                 "rgba(247, 251, 252, 0.500)"
#             ],
#             [
#                 0.02020202020202022,
#                 "rgba(240, 247, 250, 0.500)"
#             ],
#             [
#                 0.030303030303030276,
#                 "rgba(232, 243, 247, 0.500)"
#             ],
#             [
#                 0.04040404040404044,
#                 "rgba(224, 240, 245, 0.500)"
#             ],
#             [
#                 0.0505050505050505,
#                 "rgba(216, 236, 242, 0.500)"
#             ],
#             [
#                 0.06060606060606055,
#                 "rgba(209, 232, 240, 0.500)"
#             ],
#             [
#                 0.07070707070707072,
#                 "rgba(201, 228, 237, 0.500)"
#             ],
#             [
#                 0.08080808080808077,
#                 "rgba(193, 224, 234, 0.500)"
#             ],
#             [
#                 0.09090909090909094,
#                 "rgba(185, 220, 232, 0.500)"
#             ],
#             [
#                 0.101010101010101,
#                 "rgba(178, 216, 229, 0.500)"
#             ],
#             [
#                 0.11111111111111116,
#                 "rgba(170, 212, 227, 0.500)"
#             ],
#             [
#                 0.12121212121212122,
#                 "rgba(162, 209, 224, 0.500)"
#             ],
#             [
#                 0.13131313131313127,
#                 "rgba(155, 205, 222, 0.500)"
#             ],
#             [
#                 0.14141414141414144,
#                 "rgba(147, 201, 219, 0.500)"
#             ],
#             [
#                 0.1515151515151515,
#                 "rgba(139, 197, 216, 0.500)"
#             ],
#             [
#                 0.16161616161616166,
#                 "rgba(131, 193, 214, 0.500)"
#             ],
#             [
#                 0.1717171717171717,
#                 "rgba(124, 189, 211, 0.500)"
#             ],
#             [
#                 0.18181818181818177,
#                 "rgba(116, 185, 209, 0.500)"
#             ],
#             [
#                 0.19191919191919193,
#                 "rgba(108, 182, 206, 0.500)"
#             ],
#             [
#                 0.202020202020202,
#                 "rgba(100, 178, 203, 0.500)"
#             ],
#             [
#                 0.21212121212121215,
#                 "rgba(93, 174, 201, 0.500)"
#             ],
#             [
#                 0.2222222222222222,
#                 "rgba(85, 170, 198, 0.500)"
#             ],
#             [
#                 0.23232323232323238,
#                 "rgba(77, 166, 196, 0.500)"
#             ],
#             [
#                 0.24242424242424243,
#                 "rgba(70, 162, 193, 0.500)"
#             ],
#             [
#                 0.2525252525252525,
#                 "rgba(62, 158, 191, 0.500)"
#             ],
#             [
#                 0.26262626262626265,
#                 "rgba(54, 155, 188, 0.500)"
#             ],
#             [
#                 0.2727272727272727,
#                 "rgba(46, 151, 185, 0.500)"
#             ],
#             [
#                 0.2828282828282829,
#                 "rgba(39, 147, 183, 0.500)"
#             ],
#             [
#                 0.29292929292929293,
#                 "rgba(31, 143, 180, 0.500)"
#             ],
#             [
#                 0.303030303030303,
#                 "rgba(23, 139, 178, 0.500)"
#             ],
#             [
#                 0.31313131313131315,
#                 "rgba(15, 135, 175, 0.500)"
#             ],
#             [
#                 0.3232323232323232,
#                 "rgba(8, 131, 173, 0.500)"
#             ],
#             [
#                 0.33333333333333337,
#                 "rgba(0, 127, 170, 0.500)"
#             ],
#             [
#                 0.3434343434343434,
#                 "rgba(0, 124, 167, 0.500)"
#             ],
#             [
#                 0.3535353535353535,
#                 "rgba(0, 120, 165, 0.500)"
#             ],
#             [
#                 0.36363636363636365,
#                 "rgba(0, 116, 162, 0.500)"
#             ],
#             [
#                 0.3737373737373737,
#                 "rgba(0, 112, 160, 0.500)"
#             ],
#             [
#                 0.38383838383838387,
#                 "rgba(0, 108, 157, 0.500)"
#             ],
#             [
#                 0.3939393939393939,
#                 "rgba(0, 104, 155, 0.500)"
#             ],
#             [
#                 0.4040404040404041,
#                 "rgba(0, 100, 152, 0.500)"
#             ],
#             [
#                 0.41414141414141414,
#                 "rgba(0, 97, 149, 0.500)"
#             ],
#             [
#                 0.4242424242424242,
#                 "rgba(0, 93, 147, 0.500)"
#             ],
#             [
#                 0.43434343434343436,
#                 "rgba(0, 89, 144, 0.500)"
#             ],
#             [
#                 0.4444444444444444,
#                 "rgba(0, 85, 142, 0.500)"
#             ],
#             [
#                 0.4545454545454546,
#                 "rgba(0, 81, 139, 0.500)"
#             ],
#             [
#                 0.46464646464646464,
#                 "rgba(0, 77, 137, 0.500)"
#             ],
#             [
#                 0.4747474747474747,
#                 "rgba(0, 73, 134, 0.500)"
#             ],
#             [
#                 0.48484848484848486,
#                 "rgba(0, 70, 131, 0.500)"
#             ],
#             [
#                 0.4949494949494949,
#                 "rgba(0, 66, 129, 0.500)"
#             ],
#             [
#                 0.505050505050505,
#                 "rgba(0, 62, 126, 0.500)"
#             ],
#             [
#                 0.5151515151515151,
#                 "rgba(0, 58, 124, 0.500)"
#             ],
#             [
#                 0.5252525252525253,
#                 "rgba(0, 54, 121, 0.500)"
#             ],
#             [
#                 0.5353535353535354,
#                 "rgba(0, 50, 118, 0.500)"
#             ],
#             [
#                 0.5454545454545454,
#                 "rgba(0, 46, 116, 0.500)"
#             ],
#             [
#                 0.5555555555555556,
#                 "rgba(0, 42, 113, 0.500)"
#             ],
#             [
#                 0.5656565656565656,
#                 "rgba(0, 39, 111, 0.500)"
#             ],
#             [
#                 0.5757575757575757,
#                 "rgba(0, 35, 108, 0.500)"
#             ],
#             [
#                 0.5858585858585859,
#                 "rgba(0, 31, 106, 0.500)"
#             ],
#             [
#                 0.595959595959596,
#                 "rgba(0, 27, 103, 0.500)"
#             ],
#             [
#                 0.6060606060606061,
#                 "rgba(0, 23, 100, 0.500)"
#             ],
#             [
#                 0.6161616161616161,
#                 "rgba(0, 19, 98, 0.500)"
#             ],
#             [
#                 0.6262626262626263,
#                 "rgba(0, 15, 95, 0.500)"
#             ],
#             [
#                 0.6363636363636364,
#                 "rgba(0, 12, 93, 0.500)"
#             ],
#             [
#                 0.6464646464646464,
#                 "rgba(0, 8, 90, 0.500)"
#             ],
#             [
#                 0.6565656565656566,
#                 "rgba(0, 4, 88, 0.500)"
#             ],
#             [
#                 0.6666666666666667,
#                 "rgba(0, 0, 85, 0.500)"
#             ],
#             [
#                 0.6767676767676767,
#                 "rgba(0, 4, 82, 0.500)"
#             ],
#             [
#                 0.6868686868686869,
#                 "rgba(0, 8, 80, 0.500)"
#             ],
#             [
#                 0.696969696969697,
#                 "rgba(0, 12, 77,
